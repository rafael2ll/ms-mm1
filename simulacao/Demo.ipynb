# %%
from simulacao import Distribuicoes
from simulacao import Variaveis
from simulacao import Simulacao
from simulacao import GeradorSimulacaoExponencial
from simulacao import MM1

# %% [markdown]
# ## Gerando uma simulação com distribuição Normal.

# %%
vars = Variaveis()
vars.set_tes(Distribuicoes.NORMAL.value['func'])
vars.set_tec(Distribuicoes.NORMAL.value['func'])
s = Simulacao(variaveis=vars, tempo_limite=1000)
s.simular_tudo()
df = s.get_tabela()
df
# Out:
#     cliente        tec  tempo_chegada_relogio         tes  \
# 0         1   6.583733               6.583733    5.840343
# 1         2   2.840416               9.424149  140.412693
# 2         3   3.702219              13.126368   28.237758
# 3         4   3.840836              16.967204   44.658371
# 4         5   2.344324              19.311527   30.456079
# 5         6   1.856105              21.167632  251.633103
# 6         7   5.525265              26.692897   49.145516
# 7         8   8.297339              34.990236   95.909070
# 8         9  10.021110              45.011346   65.629580
# 9        10   1.371130              46.382476   55.961563
# 10       11  11.589836              57.972312  103.483326
# 11       12   2.108500              60.080811   18.299228
# 12       13   3.673248              63.754060  192.413436
#
#     tempo_inicio_servico_relogio  tempo_fila  tempo_final_servico_relogio  \
# 0                       6.583733    0.000000                    12.424076
# 1                      12.424076    2.999927                   152.836768
# 2                     152.836768  139.710400                   181.074526
# 3                     181.074526  164.107323                   225.732897
# 4                     225.732897  206.421370                   256.188976
# 5                     256.188976  235.021344                   507.822079
# 6                     507.822079  481.129182                   556.967595
# 7                     556.967595  521.977359                   652.876664
# 8                     652.876664  607.865318                   718.506244
# 9                     718.506244  672.123769                   774.467807
# 10                    774.467807  716.495495                   877.951133
# 11                    877.951133  817.870322                   896.250361
# 12                    896.250361  832.496302                  1088.663797
#
#     tempo_cliente_sistema  tempo_livre_operador
# 0                5.840343              6.583733
# 1              143.412620              0.000000
# 2              167.948158              0.000000
# 3              208.765694              0.000000
# 4              236.877449              0.000000
# 5              486.654447              0.000000
# 6              530.274698              0.000000
# 7              617.886429              0.000000
# 8              673.494898              0.000000
# 9              728.085331              0.000000
# 10             819.978821              0.000000
# 11             836.169550              0.000000
# 12            1024.909738              0.000000

# %% [markdown]
# ## Gerando uma simulação com distribuição exponencial utilizando o gerador.

# %%
dfS = GeradorSimulacaoExponencial()
df = dfS.dfSimulacao
df
# Out:
#     cliente        tec  tempo_chegada_relogio         tes  \
# 0         1  13.255318              13.255318    4.207566
# 1         2   6.573783              19.829101   21.555353
# 2         3  17.740112              37.569213   47.216792
# 3         4  10.180630              47.749843   14.648782
# 4         5  33.243964              80.993807   73.807328
# 5         6  14.372064              95.365871   67.122780
# 6         7   9.747566             105.113437   29.788761
# 7         8  14.235356             119.348793   33.189147
# 8         9   7.707428             127.056222    6.969016
# 9        10  16.870309             143.926530  240.188784
# 10       11  49.914232             193.840762   66.110320
# 11       12   3.131257             196.972018  239.023957
# 12       13   6.197852             203.169870   86.781144
# 13       14   1.999273             205.169143   43.868731
# 14       15   0.044466             205.213609   16.778618
#
#     tempo_inicio_servico_relogio  tempo_fila  tempo_final_servico_relogio  \
# 0                      13.255318    0.000000                    17.462884
# 1                      19.829101    0.000000                    41.384454
# 2                      41.384454    3.815240                    88.601246
# 3                      88.601246   40.851403                   103.250028
# 4                     103.250028   22.256221                   177.057357
# 5                     177.057357   81.691485                   244.180137
# 6                     244.180137  139.066700                   273.968898
# 7                     273.968898  154.620105                   307.158045
# 8                     307.158045  180.101824                   314.127061
# 9                     314.127061  170.200531                   554.315846
# 10                    554.315846  360.475084                   620.426166
# 11                    620.426166  423.454147                   859.450123
# 12                    859.450123  656.280253                   946.231267
# 13                    946.231267  741.062124                   990.099998
# 14                    990.099998  784.886389                  1006.878616
#
#     tempo_cliente_sistema  tempo_livre_operador
# 0                4.207566             13.255318
# 1               21.555353              2.366217
# 2               51.032033              0.000000
# 3               55.500185              0.000000
# 4               96.063550              0.000000
# 5              148.814266              0.000000
# 6              168.855461              0.000000
# 7              187.809252              0.000000
# 8              187.070840              0.000000
# 9              410.389316              0.000000
# 10             426.585404              0.000000
# 11             662.478104              0.000000
# 12             743.061397              0.000000
# 13             784.930855              0.000000
# 14             801.665007              0.000000

# %% [markdown]
# ## Gerando um modelo M/M/1 utilizando o DataFrame criado pelo gerador

# %%
mm1 = MM1(df)
mm1.calcularTudo()
gerais = mm1.plotMetricasGerais()
cliente = mm1.plotMetricasCliente()
tempo = mm1.plotMetricasTempo()

# %% [markdown]
# ## Gerando um modelo M/M/1 utilizando outros valores

# %%
mm1 = MM1(chegada = 10, atendimento = 15)
mm1.calcularTudo()
gerais = mm1.plotMetricasGerais()
cliente = mm1.plotMetricasCliente()
tempo = mm1.plotMetricasTempo()
